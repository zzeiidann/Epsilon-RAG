# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load PDF files from a directory

PATH = "/Users/mraffyzeidan/Documents/Code/Epsilon/data"

def load_documents():
    document_loaders = PyPDFDirectoryLoader(PATH)
    return document_loaders.load()

# %%
Document = load_documents()

def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

chunks = split_documents(Document)
# Out:
# /Users/mraffyzeidan/anaconda3/lib/python3.11/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
from langchain.embeddings import HuggingFaceEmbeddings

def get_embedding_function():
    model_path = "bert-base-multilingual-cased"
    model_kwargs = {'device': 'cpu'}  # Use 'cuda' for GPU if available

    embeddings = HuggingFaceEmbeddings(model_name=model_path, model_kwargs=model_kwargs)
    return embeddings

# %%
from get_embedding_function import get_embedding_function
from langchain.vectorstores.chroma import Chroma

Doc = list[Document]
def add_to_chroma(chunks, Doc):
    db = Chroma(
        persistence_path="chroma", embedding_function=get_embedding_function()
    )
    db.add_documents(new_chunks, ids=new_chunks_ids)
    db.persist()

# %%
for chunk in chunks :
    source = chunk.metadata.get("source")
    page = chunk.metadata.get("page")
    current_page_id = f"{source}_{page}"
